# %% [markdown]
# # Bad 1h output & debugging

# %%
import sys
sys.path.insert(0, '_libs/')

# %%
import glob
import scipy.io
import numpy as np
import netCDF4 as nc
import NEMO_tools as Nts
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
% matplotlib inline

# %%
ptrc_obj = nc.Dataset('_data\EXP14_1h_20100101_20100101_ptrc_T.nc')
Ba=ptrc_obj.variables['Ba'][:]
#d18O=ptrc_obj.variables['d18O'][:]
nav_lat=ptrc_obj.variables['nav_lat'][:]
nav_lon=ptrc_obj.variables['nav_lon'][:]
deptht=ptrc_obj.variables['deptht'][:]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-d6b009230b12> in <module>()
# ----> 1 ptrc_obj = nc.Dataset('_data\EXP14_1h_20100101_20100101_ptrc_T.nc')
#       2 Ba=ptrc_obj.variables['Ba'][:]
#       3 #d18O=ptrc_obj.variables['d18O'][:]
#       4 nav_lat=ptrc_obj.variables['nav_lat'][:]
#       5 nav_lon=ptrc_obj.variables['nav_lon'][:]
#
# netCDF4.pyx in netCDF4.Dataset.__init__ (netCDF4.c:19736)()
#
# RuntimeError: No such file or directory

# %%
L = 0
lev1 = range(0, 110, 10)
lev2 = [-2, -1, 0, 1, 2]

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.gca()

proj=Basemap(projection='npstere', resolution='c', boundinglat=55, lon_0=90, round=True, ax=ax)
proj.drawmeridians(np.arange(0, 360, 60), labels=[1, 1, 1, 1], fontsize=10, latmax=90,linewidth=0)
proj.fillcontinents(color=[0.5, 0.5, 0.5], lake_color=None)
proj.drawcoastlines(linewidth=2.0, linestyle='-', color='k')
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, Ba[19, 0, :, :], lev1, cmap=plt.cm.gist_ncar_r, extend='both')
#proj.contour(x, y, Ba[19, 0, :, :], lev1, linewidths=1.5, colors=('gray',))

#proj.plot(x[700, 300], y[700, 300], 'ro')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('nM', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev1)

# %%
fig=plt.figure(figsize=(10, 10))
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, Ba[19, 0, :, :], lev1, cmap=plt.cm.gist_ncar_r, extend='both')
#proj.contour(x, y, Ba[19, 0, :, :], lev1, linewidths=1.5, colors=('gray',))

#proj.plot(x[700, 300], y[700, 300], 'ro')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('nM', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev1)

# %% [markdown]
# # emp = emps = 0

# %%
ptrc_obj = nc.Dataset('/ocean/yingkai/GEOTRACES/NEMO-CODE/NEMOGCM/CONFIG/ANHA4_OFF/EXP00/EXP17_1h_20100101_20100101_ptrc_T.nc')
Ba1=ptrc_obj.variables['Ba'][:]
nav_lat=ptrc_obj.variables['nav_lat'][:]
nav_lon=ptrc_obj.variables['nav_lon'][:]
deptht=ptrc_obj.variables['deptht'][:]

# %%
fig=plt.figure(figsize=(10, 10))
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, Ba1[-1, 0, :, :], lev1, cmap=plt.cm.gist_ncar_r, extend='both')
#proj.contour(x, y, Ba[19, 0, :, :], lev1, linewidths=1.5, colors=('gray',))

proj.plot(x[1, 350], y[1, 350], 'ro', ms=15)

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('nM', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev1)

# %% [markdown]
# # The right emp/emps

# %%
ptrc_obj = nc.Dataset('/ocean/yingkai/GEOTRACES/NEMO-CODE/NEMOGCM/CONFIG/ANHA4_OFF/EXP00/EXP18_1h_20100101_20100101_ptrc_T.nc')
Ba2=ptrc_obj.variables['Ba'][:]

# %%
fig=plt.figure(figsize=(10, 10))
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, Ba2[-1, 0, :, :], lev1, cmap=plt.cm.gist_ncar_r, extend='both')
#proj.contour(x, y, Ba[19, 0, :, :], lev1, linewidths=1.5, colors=('gray',))

#proj.plot(x[700, 300], y[700, 300], 'ro')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('nM', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev1)

# %%
np.nansum(Ba2[-1, 0, :, :]-Ba1[-1, 0, :, :])
# Out:
# 4811879.0

# %%
fig=plt.figure(figsize=(10, 10))
ax = fig.gca()
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, Ba2[-1, 0, :, :]-Ba1[-1, 0, :, :], np.array(lev2)*0.01, cmap=plt.cm.RdBu_r, extend='both')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('nM', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(np.array(lev2)*0.01)

ax.set_title('With dilution - without')

# %% [markdown]
# # Forcing

# %%
ANHA4_obj = nc.Dataset('_data\ANHA4-EXH001_icemod_y2014m08d13.nc')
safl=ptrc_obj.variables['iocesafl'][:]
salin=ptrc_obj.variables['isssalin'][:]
#d18O=ptrc_obj.variables['d18O'][:]
nav_lat=ptrc_obj.variables['nav_lat'][:]
nav_lon=ptrc_obj.variables['nav_lon'][:]
#deptht=ptrc_obj.variables['deptht'][:]

# %%
lev = [-15, -12, -9, -6, -3, -1, 1, 3, 6, 9, 12, 15]
fig=plt.figure(figsize=(10, 10))
ax = fig.gca()
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, safl[0, :, :], lev, cmap=plt.cm.RdBu_r, extend='both')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('salf', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev)

# %%
lev = np.arange(3, 38, 3)
fig=plt.figure(figsize=(10, 10))
ax = fig.gca()
proj=Basemap(projection='ortho',lon_0=-32.5, lat_0=37.5, resolution='l') # http://matplotlib.org/basemap/users/omerc.html
proj.drawcoastlines(linewidth=1.5, linestyle='-', color='k', zorder=3)  
proj.drawlsmask(land_color=[0.5, 0.5, 0.5], ocean_color='None', lsmask=None, zorder=2)
x, y=proj(nav_lon, nav_lat)
# Ba
CS=proj.contourf(x, y, salin[0, :, :], lev, cmap=plt.cm.gist_ncar_r, extend='both')

cax = fig.add_axes([0.25, 0.05, 0.5, 0.03])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('sss_m', fontsize=12)
CBar.ax.tick_params(axis='x', length=22)
CBar.set_ticks(lev)
